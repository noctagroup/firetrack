# %%
# !pip install scikit-learn matplotlib

# %%
import psycopg2 as pg
import psycopg2.extras as ex
import logging
import httpx
import numpy as np
import rasterio
import os
from sklearn.cluster import KMeans
from rasterio import Affine
from rasterio.enums import Resampling
from rasterio.transform import from_origin

# %%
FENOMENO_ID = 35

# %%
print("Iniciando conexão")
conn = pg.connect("postgresql://postgres:postgres@localhost:5432/postgres")
if conn.status == 1:
    print("Conexão concluída")
else:
    raise Exception("Não foi possível se conectar")
# Out:
# Iniciando conexão
# Conexão concluída

# %%
select_pre_images = """
SELECT
    pp.id AS id_par,
    pp.candidato_pre_id AS id_pre,
    cc.nir,
    cc.red,
    cc.datetime
FROM
    public.candidatos_candidato cc
INNER JOIN
    public.pares_pares pp
    ON cc.id = pp.candidato_pre_id
where
	pp.fenomeno_id = %s;
"""

# %%
select_pos_images = """
SELECT
    pp.id AS id_par,
    pp.candidato_pos_id AS id_pos,
    cc.nir,
    cc.red,
    cc.datetime
FROM
    public.candidatos_candidato cc
INNER JOIN
    public.pares_pares pp
    ON cc.id = pp.candidato_pos_id
WHERE
    pp.fenomeno_id = %s;
"""

# %%
with conn.cursor(name="INDEX_CRETION_JOB") as cur:
    cur.execute(select_pre_images, (FENOMENO_ID,))
    images_pre = cur.fetchall()

# %%
images_pre
# Out:
# [(8,
#   2789,
#   'https://data.inpe.br/bdc/data/cbers4/2025_01/CBERS_4_AWFI_DRD_2025_01_05.13_38_00_CB11/170_099_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20250105_170_099_L2_BAND16.tif',
#   'https://data.inpe.br/bdc/data/cbers4/2025_01/CBERS_4_AWFI_DRD_2025_01_05.13_38_00_CB11/170_099_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20250105_170_099_L2_BAND15.tif',
#   datetime.datetime(2025, 1, 5, 13, 38, tzinfo=datetime.timezone.utc)),
#  (9,
#   2850,
#   'https://data.inpe.br/bdc/data/cbers4/2024_05/CBERS_4_AWFI_DRD_2024_05_13.13_54_00_CB11/171_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20240513_171_093_L2_BAND16.tif',
#   'https://data.inpe.br/bdc/data/cbers4/2024_05/CBERS_4_AWFI_DRD_2024_05_13.13_54_00_CB11/171_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20240513_171_093_L2_BAND15.tif',
#   datetime.datetime(2024, 5, 13, 13, 54, tzinfo=datetime.timezone.utc)),
#  (10,
#   2810,
#   'https://data.inpe.br/bdc/data/cbers4/2024_11/CBERS_4_AWFI_DRD_2024_11_11.13_44_00_CB11/171_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20241111_171_093_L2_BAND16.tif',
#   'https://data.inpe.br/bdc/data/cbers4/2024_11/CBERS_4_AWFI_DRD_2024_11_11.13_44_00_CB11/171_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20241111_171_093_L2_BAND15.tif',
#   datetime.datetime(2024, 11, 11, 13, 44, tzinfo=datetime.timezone.utc)),
#  (11,
#   2802,
#   'https://data.inpe.br/bdc/data/cbers4/2024_12/CBERS_4_AWFI_DRD_2024_12_07.13_43_30_CB11/171_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20241207_171_093_L2_BAND16.tif',
#   'https://data.inpe.br/bdc/data/cbers4/2024_12/CBERS_4_AWFI_DRD_2024_12_07.13_43_30_CB11/171_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20241207_171_093_L2_BAND15.tif',
#   datetime.datetime(2024, 12, 7, 13, 43, 30, tzinfo=datetime.timezone.utc)),
#  (12,
#   2792,
#   'https://data.inpe.br/bdc/data/cbers4/2025_01/CBERS_4_AWFI_DRD_2025_01_02.13_42_00_CB11/171_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20250102_171_093_L2_BAND16.tif',
#   'https://data.inpe.br/bdc/data/cbers4/2025_01/CBERS_4_AWFI_DRD_2025_01_02.13_42_00_CB11/171_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20250102_171_093_L2_BAND15.tif',
#   datetime.datetime(2025, 1, 2, 13, 42, tzinfo=datetime.timezone.utc)),
#  (13,
#   2782,
#   'https://data.inpe.br/bdc/data/cbers4/2025_01/CBERS_4_AWFI_DRD_2025_01_28.13_40_00_CB11/171_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20250128_171_093_L2_BAND16.tif',
#   'https://data.inpe.br/bdc/data/cbers4/2025_01/CBERS_4_AWFI_DRD_2025_01_28.13_40_00_CB11/171_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20250128_171_093_L2_BAND15.tif',
#   datetime.datetime(2025, 1, 28, 13, 40, tzinfo=datetime.timezone.utc)),
#  (14,
#   2851,
#   'https://data.inpe.br/bdc/data/cbers4/2024_05/CBERS_4_AWFI_DRD_2024_05_13.13_54_00_CB11/171_099_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20240513_171_099_L2_BAND16.tif',
#   'https://data.inpe.br/bdc/data/cbers4/2024_05/CBERS_4_AWFI_DRD_2024_05_13.13_54_00_CB11/171_099_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20240513_171_099_L2_BAND15.tif',
#   datetime.datetime(2024, 5, 13, 13, 54, tzinfo=datetime.timezone.utc)),
#  (15,
#   2803,
#   'https://data.inpe.br/bdc/data/cbers4/2024_12/CBERS_4_AWFI_DRD_2024_12_07.13_43_30_CB11/171_099_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20241207_171_099_L2_BAND16.tif',
#   'https://data.inpe.br/bdc/data/cbers4/2024_12/CBERS_4_AWFI_DRD_2024_12_07.13_43_30_CB11/171_099_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20241207_171_099_L2_BAND15.tif',
#   datetime.datetime(2024, 12, 7, 13, 43, 30, tzinfo=datetime.timezone.utc)),
#  (16,
#   2793,
#   'https://data.inpe.br/bdc/data/cbers4/2025_01/CBERS_4_AWFI_DRD_2025_01_02.13_42_00_CB11/171_099_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20250102_171_099_L2_BAND16.tif',
#   'https://data.inpe.br/bdc/data/cbers4/2025_01/CBERS_4_AWFI_DRD_2025_01_02.13_42_00_CB11/171_099_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20250102_171_099_L2_BAND15.tif',
#   datetime.datetime(2025, 1, 2, 13, 42, tzinfo=datetime.timezone.utc)),
#  (17,
#   2783,
#   'https://data.inpe.br/bdc/data/cbers4/2025_01/CBERS_4_AWFI_DRD_2025_01_28.13_40_00_CB11/171_099_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20250128_171_099_L2_BAND16.tif',
#   'https://data.inpe.br/bdc/data/cbers4/2025_01/CBERS_4_AWFI_DRD_2025_01_28.13_40_00_CB11/171_099_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20250128_171_099_L2_BAND15.tif',
#   datetime.datetime(2025, 1, 28, 13, 40, tzinfo=datetime.timezone.utc)),
#  (18,
#   2805,
#   'https://data.inpe.br/bdc/data/cbers4/2024_12/CBERS_4_AWFI_DRD_2024_12_04.13_47_00_CB11/172_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20241204_172_093_L2_BAND16.tif',
#   'https://data.inpe.br/bdc/data/cbers4/2024_12/CBERS_4_AWFI_DRD_2024_12_04.13_47_00_CB11/172_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20241204_172_093_L2_BAND15.tif',
#   datetime.datetime(2024, 12, 4, 13, 47, tzinfo=datetime.timezone.utc)),
#  (19,
#   2795,
#   'https://data.inpe.br/bdc/data/cbers4/2024_12/CBERS_4_AWFI_DRD_2024_12_30.13_45_30_CB11/172_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20
177_093_L2_BAND15.tif',
#   datetime.datetime(2024, 5, 21, 14, 16, 30, tzinfo=datetime.timezone.utc)),
#  (36,
#   2832,
#   'https://data.inpe.br/bdc/data/cbers4/2024_06/CBERS_4_AWFI_DRD_2024_06_16.14_15_30_CB11/177_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20240616_177_093_L2_BAND16.tif',
#   'https://data.inpe.br/bdc/data/cbers4/2024_06/CBERS_4_AWFI_DRD_2024_06_16.14_15_30_CB11/177_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20240616_177_093_L2_BAND15.tif',
#   datetime.datetime(2024, 6, 16, 14, 15, 30, tzinfo=datetime.timezone.utc)),
#  (37,
#   2825,
#   'https://data.inpe.br/bdc/data/cbers4/2024_07/CBERS_4_AWFI_DRD_2024_07_12.14_14_30_CB11/177_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20240712_177_093_L2_BAND16.tif',
#   'https://data.inpe.br/bdc/data/cbers4/2024_07/CBERS_4_AWFI_DRD_2024_07_12.14_14_30_CB11/177_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20240712_177_093_L2_BAND15.tif',
#   datetime.datetime(2024, 7, 12, 14, 14, 30, tzinfo=datetime.timezone.utc)),
#  (38,
#   2809,
#   'https://data.inpe.br/bdc/data/cbers4/2024_11/CBERS_4_AWFI_DRD_2024_11_19.14_05_30_CB11/177_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20241119_177_093_L2_BAND16.tif',
#   'https://data.inpe.br/bdc/data/cbers4/2024_11/CBERS_4_AWFI_DRD_2024_11_19.14_05_30_CB11/177_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20241119_177_093_L2_BAND15.tif',
#   datetime.datetime(2024, 11, 19, 14, 5, 30, tzinfo=datetime.timezone.utc)),
#  (39,
#   2848,
#   'https://data.inpe.br/bdc/data/cbers4/2024_05/CBERS_4_AWFI_DRD_2024_05_18.14_20_30_CB11/178_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20240518_178_093_L2_BAND16.tif',
#   'https://data.inpe.br/bdc/data/cbers4/2024_05/CBERS_4_AWFI_DRD_2024_05_18.14_20_30_CB11/178_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20240518_178_093_L2_BAND15.tif',
#   datetime.datetime(2024, 5, 18, 14, 20, 30, tzinfo=datetime.timezone.utc)),
#  (40,
#   2849,
#   'https://data.inpe.br/bdc/data/cbers4/2024_05/CBERS_4_AWFI_DRD_2024_05_18.14_20_30_CB11/178_099_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20240518_178_099_L2_BAND16.tif',
#   'https://data.inpe.br/bdc/data/cbers4/2024_05/CBERS_4_AWFI_DRD_2024_05_18.14_20_30_CB11/178_099_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20240518_178_099_L2_BAND15.tif',
#   datetime.datetime(2024, 5, 18, 14, 20, 30, tzinfo=datetime.timezone.utc)),
#  (41,
#   2835,
#   'https://data.inpe.br/bdc/data/cbers4/2024_06/CBERS_4_AWFI_DRD_2024_06_10.14_23_30_CB11/179_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20240610_179_093_L2_BAND16.tif',
#   'https://data.inpe.br/bdc/data/cbers4/2024_06/CBERS_4_AWFI_DRD_2024_06_10.14_23_30_CB11/179_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20240610_179_093_L2_BAND15.tif',
#   datetime.datetime(2024, 6, 10, 14, 23, 30, tzinfo=datetime.timezone.utc)),
#  (42,
#   2790,
#   'https://data.inpe.br/bdc/data/cbers4/2025_01/CBERS_4_AWFI_DRD_2025_01_04.14_13_00_CB11/179_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20250104_179_093_L2_BAND16.tif',
#   'https://data.inpe.br/bdc/data/cbers4/2025_01/CBERS_4_AWFI_DRD_2025_01_04.14_13_00_CB11/179_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20250104_179_093_L2_BAND15.tif',
#   datetime.datetime(2025, 1, 4, 14, 13, tzinfo=datetime.timezone.utc)),
#  (43,
#   2804,
#   'https://data.inpe.br/bdc/data/cbers4/2024_12/CBERS_4_AWFI_DRD_2024_12_06.14_18_30_CB11/180_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20241206_180_093_L2_BAND16.tif',
#   'https://data.inpe.br/bdc/data/cbers4/2024_12/CBERS_4_AWFI_DRD_2024_12_06.14_18_30_CB11/180_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20241206_180_093_L2_BAND15.tif',
#   datetime.datetime(2024, 12, 6, 14, 18, 30, tzinfo=datetime.timezone.utc)),
#  (44,
#   2796,
#   'https://data.inpe.br/bdc/data/cbers4/2024_12/CBERS_4_AWFI_DRD_2024_12_29.14_20_30_CB11/181_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20241229_181_093_L2_BAND16.tif',
#   'https://data.inpe.br/bdc/data/cbers4/2024_12/CBERS_4_AWFI_DRD_2024_12_29.14_20_30_CB11/181_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20241229_181_093_L2_BAND15.tif',
#   datetime.datetime(2024, 12, 29, 14, 20, 30, tzinfo=datetime.timezone.utc)),
#  (45,
#   2786,
#   'https://data.inpe.br/bdc/data/cbers4/2025_01/CBERS_4_AWFI_DRD_2025_01_24.14_19_30_CB11/181_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20250124_181_093_L2_BAND16.tif',
#   'https://data.inpe.br/bdc/data/cbers4/2025_01/CBERS_4_AWFI_DRD_2025_01_24.14_19_30_CB11/181_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20250124_181_093_L2_BAND15.tif',
#   datetime.datetime(2025, 1, 24, 14, 19, 30, tzinfo=datetime.timezone.utc))]

# %%
with conn.cursor(name="INDEX_CRETION_JOB") as cur:
    cur.execute(select_pos_images, (FENOMENO_ID,))
    images_pos = cur.fetchall()

# %%
images_pos
# Out:
# [(8,
#   2780,
#   'https://data.inpe.br/bdc/data/cbers4/2025_01/CBERS_4_AWFI_DRD_2025_01_31.13_36_30_CB11/170_099_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20250131_170_099_L2_BAND16.tif',
#   'https://data.inpe.br/bdc/data/cbers4/2025_01/CBERS_4_AWFI_DRD_2025_01_31.13_36_30_CB11/170_099_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20250131_170_099_L2_BAND15.tif',
#   datetime.datetime(2025, 1, 31, 13, 36, 30, tzinfo=datetime.timezone.utc)),
#  (9,
#   2836,
#   'https://data.inpe.br/bdc/data/cbers4/2024_06/CBERS_4_AWFI_DRD_2024_06_08.13_52_30_CB11/171_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20240608_171_093_L2_BAND16.tif',
#   'https://data.inpe.br/bdc/data/cbers4/2024_06/CBERS_4_AWFI_DRD_2024_06_08.13_52_30_CB11/171_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20240608_171_093_L2_BAND15.tif',
#   datetime.datetime(2024, 6, 8, 13, 52, 30, tzinfo=datetime.timezone.utc)),
#  (10,
#   2802,
#   'https://data.inpe.br/bdc/data/cbers4/2024_12/CBERS_4_AWFI_DRD_2024_12_07.13_43_30_CB11/171_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20241207_171_093_L2_BAND16.tif',
#   'https://data.inpe.br/bdc/data/cbers4/2024_12/CBERS_4_AWFI_DRD_2024_12_07.13_43_30_CB11/171_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20241207_171_093_L2_BAND15.tif',
#   datetime.datetime(2024, 12, 7, 13, 43, 30, tzinfo=datetime.timezone.utc)),
#  (11,
#   2792,
#   'https://data.inpe.br/bdc/data/cbers4/2025_01/CBERS_4_AWFI_DRD_2025_01_02.13_42_00_CB11/171_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20250102_171_093_L2_BAND16.tif',
#   'https://data.inpe.br/bdc/data/cbers4/2025_01/CBERS_4_AWFI_DRD_2025_01_02.13_42_00_CB11/171_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20250102_171_093_L2_BAND15.tif',
#   datetime.datetime(2025, 1, 2, 13, 42, tzinfo=datetime.timezone.utc)),
#  (12,
#   2782,
#   'https://data.inpe.br/bdc/data/cbers4/2025_01/CBERS_4_AWFI_DRD_2025_01_28.13_40_00_CB11/171_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20250128_171_093_L2_BAND16.tif',
#   'https://data.inpe.br/bdc/data/cbers4/2025_01/CBERS_4_AWFI_DRD_2025_01_28.13_40_00_CB11/171_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20250128_171_093_L2_BAND15.tif',
#   datetime.datetime(2025, 1, 28, 13, 40, tzinfo=datetime.timezone.utc)),
#  (13,
#   2768,
#   'https://data.inpe.br/bdc/data/cbers4/2025_02/CBERS_4_AWFI_DRD_2025_02_23.13_38_30_CB11/171_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20250223_171_093_L2_BAND16.tif',
#   'https://data.inpe.br/bdc/data/cbers4/2025_02/CBERS_4_AWFI_DRD_2025_02_23.13_38_30_CB11/171_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20250223_171_093_L2_BAND15.tif',
#   datetime.datetime(2025, 2, 23, 13, 38, 30, tzinfo=datetime.timezone.utc)),
#  (14,
#   2837,
#   'https://data.inpe.br/bdc/data/cbers4/2024_06/CBERS_4_AWFI_DRD_2024_06_08.13_52_30_CB11/171_099_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20240608_171_099_L2_BAND16.tif',
#   'https://data.inpe.br/bdc/data/cbers4/2024_06/CBERS_4_AWFI_DRD_2024_06_08.13_52_30_CB11/171_099_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20
CB11/181_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20250124_181_093_L2_BAND15.tif',
#   datetime.datetime(2025, 1, 24, 14, 19, 30, tzinfo=datetime.timezone.utc)),
#  (45,
#   2771,
#   'https://data.inpe.br/bdc/data/cbers4/2025_02/CBERS_4_AWFI_DRD_2025_02_19.14_18_00_CB11/181_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20250219_181_093_L2_BAND16.tif',
#   'https://data.inpe.br/bdc/data/cbers4/2025_02/CBERS_4_AWFI_DRD_2025_02_19.14_18_00_CB11/181_093_0/2_BC_UTM_WGS84/CBERS_4_AWFI_20250219_181_093_L2_BAND15.tif',
#   datetime.datetime(2025, 2, 19, 14, 18, tzinfo=datetime.timezone.utc))]

# %%
def create_dirs(fenomeno_id: int, id_par: int, base_path: str = "./img"):
    """
    Cria a estrutura de diretórios:
    base_path/
      └── fenomeno_id/
          └── id_par/
              ├── pre/
              └── pos/
    """
    # Constrói o caminho base: ./fenomeno_id/id_par
    par_path = os.path.join(base_path, str(fenomeno_id), str(id_par))

    # Subdiretórios pre e pos
    pre_path = os.path.join(par_path, "pre")
    pos_path = os.path.join(par_path, "pos")

    # Cria todos os diretórios se não existirem
    os.makedirs(pre_path, exist_ok=True)
    os.makedirs(pos_path, exist_ok=True)
    
    print(f"Criados: {pre_path}, {pos_path}")
    
    return (pre_path, pos_path, par_path)

# %%
def download_file(url: str, output_path: str):
    with httpx.Client() as client:
        response = client.get(url)

        # Verifica se o download foi bem-sucedido
        response.raise_for_status()

        with open(output_path, "wb") as f:
            f.write(response.content)
    
    print(f"Arquivo salvo em: {output_path}")
    
    return output_path

# %%
def generate_ndvi(nir_file_path, red_file_path, output_path=None):
    with rio.open(nir_file_path) as nir_src, rio.open(red_file_path) as red_src:
        nir = nir_src.read(1).astype('float32')
        red = red_src.read(1).astype('float32')
        ndvi = (nir - red) / (nir + red + 1e-10)

        if output_path:
            profile = nir_src.profile
            profile.update(dtype='float32', count=1)
            with rio.open(output_path, 'w', **profile) as dst:
                dst.write(ndvi, 1)
        
        print(f"Arquivo NDVI criado e salvo em: {output_path}")

        return ndvi

# %%
for imagem_pre in images_pre:
    pre_path, pos_path, par_path = create_dirs(FENOMENO_ID, imagem_pre[0])
    nir_path = download_file(imagem_pre[2], f"{pre_path}/nir.tif")
    red_path = download_file(imagem_pre[3], f"{pre_path}/red.tif")
    generate_ndvi(nir_path, red_path, f"{par_path}/pre/ndvi.tif")

# %%
for imagem_pos in images_pos:
    pre_path, pos_path, _ = create_dirs(FENOMENO_ID, imagem_pos[0])
    download_file(imagem_pos[2], f"{pos_path}/nir.tif")
    download_file(imagem_pos[3], f"{pos_path}/red.tif")
    generate_ndvi(nir_path, red_path, f"{par_path}/pos/ndvi.tif")
# Out:
# Criados: ./img/35/8/pre, ./img/35/8/pos
# Arquivo salvo em: ./img/35/8/pos/nir.tif
# Arquivo salvo em: ./img/35/8/pos/red.tif
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 5
#       3 download_file(imagem_pos[2], f"{pos_path}/nir.tif")
#       4 download_file(imagem_pos[3], f"{pos_path}/red.tif")
# ----> 5 generate_ndvi(nir_path, red_path, f"{par_path}/pos/ndvi.tif")
#
# Cell In[36], line 5, in generate_ndvi(nir_file_path, red_file_path, output_path)
#       3 nir = nir_src.read(1).astype('float32')
#       4 red = red_src.read(1).astype('float32')
# ----> 5 ndvi = (nir - red) / (nir + red + 1e-10)
#       7 if output_path:
#       8     profile = nir_src.profile
#
# ValueError: operands could not be broadcast together with shapes (14010,16303) (14014,16302)

# %%
PAR = 8

# %%
ndvi_before_path = f"./img/{FENOMENO_ID}/{PAR}/pre/ndvi.tif"
ndvi_after_path = f"./img/{FENOMENO_ID}/{PAR}/pos/ndvi.tif"
output_mask_path = "./burn_mask.tif"

# %%
with rasterio.open(ndvi_before_path) as src1, rasterio.open(ndvi_after_path) as src2:
    ndvi_before = src1.read(1).astype(np.float32)
    ndvi_after = src2.read(1).astype(np.float32)
    meta = src1.meta.copy()
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File rasterio/_base.pyx:310, in rasterio._base.DatasetBase.__init__()
#
# File rasterio/_base.pyx:221, in rasterio._base.open_dataset()
#
# File rasterio/_err.pyx:359, in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: ./img/35/8/pos/ndvi.tif: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 with rasterio.open(ndvi_before_path) as src1, rasterio.open(ndvi_after_path) as src2:
#       2     ndvi_before = src1.read(1).astype(np.float32)
#       3     ndvi_after = src2.read(1).astype(np.float32)
#
# File /media/abreu/abreu1/trabalho/firetrack/apps/ai/venv/lib/python3.12/site-packages/rasterio/env.py:463, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     460     session = DummySession()
#     462 with env_ctor(session=session):
# --> 463     return f(*args, **kwds)
#
# File /media/abreu/abreu1/trabalho/firetrack/apps/ai/venv/lib/python3.12/site-packages/rasterio/__init__.py:356, in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, opener, **kwargs)
#     353     path = _parse_path(raw_dataset_path)
#     355 if mode == "r":
# --> 356     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#     357 elif mode == "r+":
#     358     dataset = get_writer_for_path(path, driver=driver)(
#     359         path, mode, driver=driver, sharing=sharing, **kwargs
#     360     )
#
# File rasterio/_base.pyx:312, in rasterio._base.DatasetBase.__init__()
#
# RasterioIOError: ./img/35/8/pos/ndvi.tif: No such file or directory

# %%
ndvi_diff = ndvi_after - ndvi_before

# %%
# Flatten e remover valores inválidos para clustering
valid_mask = ~np.isnan(ndvi_diff) & ~np.isinf(ndvi_diff)
ndvi_diff_valid = ndvi_diff[valid_mask].reshape(-1, 1)

# %%
kmeans = KMeans(n_clusters=2, random_state=0).fit(ndvi_diff_valid)
labels = np.zeros(ndvi_diff.shape, dtype=np.uint8)
labels[valid_mask] = kmeans.labels_

# %%
# Determinar qual cluster representa queimada (normalmente o que tem maior redução no NDVI)
cluster_means = [ndvi_diff_valid[kmeans.labels_ == i].mean() for i in range(2)]
burn_cluster = int(np.argmin(cluster_means))  # menor valor -> maior perda de vegetação

# %%
burn_mask = (labels == burn_cluster).astype(np.uint8)

# %%
meta.update(dtype=rasterio.uint8, count=1)

# %%
with rasterio.open(output_mask_path, 'w', **meta) as dst:
    dst.write(burn_mask, 1)
